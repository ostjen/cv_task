# %% [markdown]
# # Model Demo

# %%
from keras.models import load_model
import pandas as pd
import cv2
import numpy as np
from change_images import rotate
import random
# Out:
# Using TensorFlow backend.

# %%
import matplotlib.pyplot as plt

# %%
model = load_model('final_model.h5')

# %%
target = pd.read_csv('./train.truth.csv')
names = target['fn']

images = []
for name in names:
    aux = './train/' + name
    images.append(cv2.imread(aux,1))

# %%
samples = random.sample(images,5)

# %%
for i in samples:
    plt.figure()
    plt.imshow(i)

# %%
for i in samples:
    img = rotate(model,i)
    plt.figure()
    plt.imshow(img)
